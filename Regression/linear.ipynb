# %%
print("Linear Regression ")
# Out:
# Linear Regression

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sna
import pandas as pd

# %%
df = pd.read_csv("Advertising.csv")
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.drop(df.columns[[0]] , axis = 1 , inplace = True)

# %%
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df.TV.corr(df.sales)
# Out:
# np.float64(0.7822244248616061)

# %%
df.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
import seaborn as sns

sns.heatmap(df.corr() , annot = True)
# Out:
# <Axes: >
# <Axes: >

# %% [markdown]
# Use import where its needed instead of just writing all the imports
# in the top together.

# %%
# Create x and y

feature_cols = ['TV' , 'radio' , 'newspaper']
x = df[feature_cols]
y = df.sales

# instantiate and fit
from sklearn.linear_model import LinearRegression
lm1 = LinearRegression() # model lm1 refer to first model
lm1.fit(x,y)

# Print the coefficients
print(lm1.intercept_)
print(lm1.coef_)
# Out:
# 2.9388893694594085
# [ 0.04576465  0.18853002 -0.00103749]

# %% [markdown]
# y = x1.0.0457 + x2.0.1885 - x3.0.00103 + 2.9388893

# %%
lm1_preds = lm1.predict(x[['TV','radio','newspaper']])

# %%
from sklearn.metrics import r2_score , mean_squared_error

print("R^2: " , r2_score(y , lm1_preds))
print("MSE: " , mean_squared_error(y, lm1_preds))
# Out:
# R^2:  0.8972106381789522
# MSE:  2.784126314510936
