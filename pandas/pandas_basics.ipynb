# %% [markdown]
# # Pandas
#
# open-source data analysis and manipulation library built on top of Python.
# It is widely used for handling structured data (tables of rows and columns), such as data from spreadsheets or databases
#
# provides two primary data structures:
#
# **1. Series - One-dimensional labeled array**
#
# **2. DataFrame - Two-dimensional labeled data structure, similar to a table in a relational database, an Excel spreadsheet, or a SQL table.**

# %%
pip install pandas

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.3'

# %% [markdown]
# # Series
#
# A Series is like a one-dimensional array with labels
#
# By default, when you create a Series, an integer-based index (0, 1, 2, ...) is assigned to each value. However, you can also specify custom labels for the index, making it easier to reference and manipulate the data, especially in the case of non-numeric or time-based data.

# %%
data = [10, 20, 30, 40, 50]
s = pd.Series(data)
print(type(s))

# Output
print(s)
# Out:
# <class 'pandas.core.series.Series'>
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s.values
# Out:
# array([10, 20, 30, 40, 50])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# Using Lables

labelled_data=pd.Series([1,"John",3.5,"Hey"], index=["gagan","b","c","d"])
labelled_data
# Out:
# gagan       1
# b        John
# c         3.5
# d         Hey
# dtype: object

# %%
labelled_data["gagan"]
# labelled_data[0]
# Out:
# 1

# %%
labelled_data.index
# Out:
# Index(['gagan', 'b', 'c', 'd'], dtype='object')

# %% [markdown]
# ### Dictionary to Series
# Convert a dictionary to a Series (keys become indices):

# %%
# Creating using Dictionary
import numpy as np
import pandas as pd

score={"Jane":90, "Bill":80,"Elon":85,"Tom":75,"Tim":95, "Gp": None}
names=pd.Series(score) # Convert to Series 
names
# Out:
# Jane    90.0
# Bill    80.0
# Elon    85.0
# Tom     75.0
# Tim     95.0
# Gp       NaN
# dtype: float64

# %%
names["Tim"]
# Out:
# 95.0

# %% [markdown]
# ### Boolean Indexing
#
# Filter elements using conditional logic:

# %%
names[names>=85]
# Out:
# Jane    90.0
# Elon    85.0
# Tim     95.0
# dtype: float64

# %% [markdown]
# ### Modifying Values
#
# Update values using labels or conditions:

# %%
names["Tom"]=60
names[names <= 80] = 83 
names
# Out:
# Jane     90.0
# Bill     83.0
# Elon     85.0
# Tom      83.0
# Tim      95.0
# gagan    83.0
# dtype: float64

# %% [markdown]
# ### Checking Membership
#
# Verify if a label exists in the Series:

# %%
"Tom" in names
# Out:
# True

# %%
"Can" in names
# Out:
# False

# %%
names["gagan"] = 20

# %%
if "gagan" in names:
    print("What's up?")
else:
    print("Nothing")
# Out:
# What's up?

# %% [markdown]
# ### Operations

# %%
names / 10
# Out:
# Jane     9.0
# Bill     8.0
# Elon     8.5
# Tom      7.5
# Tim      9.5
# Gp       NaN
# gagan    2.0
# dtype: float64

# %%
names**2
# Out:
# Jane    8100.0
# Bill    6889.0
# Elon    7225.0
# Tom     6889.0
# Tim     9025.0
# Gp         NaN
# dtype: float64

# %% [markdown]
# ### Handling Missing Data (NaN)
#
# Handling NaN (Not a Number) values is important because they can interfere with data analysis and machine learning models
#
#  **Statistical Analysis**: calculating the mean, median, variance, or correlation, will return incorrect results or fail if there are NaN values in the data
#
#  `data = pd.Series([1, 2, np.nan, 4, 5])`
#
#  `print(data.mean())`
#
#  `print(data.mean(skipna=True))`
#
#  **Problems with Machine Learning Models**: Algorithms like linear regression, decision trees, or neural networks require complete data. If NaN values are present, they either need to be removed or replaced with something meaningful to ensure proper model training.

# %%
import numpy as np
import pandas as pd

# %%
data = pd.Series([1, 2, np.nan, 4, 5])
data.mean(skipna=True)
# Out:
# np.float64(3.0)

# %%
score={"Jane":90, "Bill":80,"Elon":85,"Tom":np.nan,"Tim":95, "Gp": None}
names=pd.Series(score) # Convert to Series 
names
# Out:
# Jane    90.0
# Bill    80.0
# Elon    85.0
# Tom      NaN
# Tim     95.0
# Gp       NaN
# dtype: float64

# %%
names.isnull()  # Returns a boolean Series
# Out:
# Jane    False
# Bill    False
# Elon    False
# Tom      True
# Tim     False
# Gp       True
# dtype: bool

# %%
names.isna()
# Out:
# Jane    False
# Bill    False
# Elon    False
# Tom      True
# Tim     False
# Gp       True
# dtype: bool

# %%
names.isna().any()
# Out:
# True

# %%
names_without_na = names.dropna(inplace=False)
# Out:
# Jane    90.0
# Bill    80.0
# Elon    85.0
# Tim     95.0
# dtype: float64

# %%
names
# Out:
# Jane    90.0
# Bill    80.0
# Elon    85.0
# Tom      NaN
# Tim     95.0
# Gp       NaN
# dtype: float64

# %%
names_without_na
# Out:
# Jane    90.0
# Bill    80.0
# Elon    85.0
# Tim     95.0
# dtype: float64

# %%
import numpy as np
names["gagan"] = np.nan

# %%
names
# Out:
# Jane     90.0
# Bill     80.0
# Elon     85.0
# Tom       NaN
# Tim      95.0
# Gp        NaN
# gagan     NaN
# dtype: float64

# %%
names.fillna(10, inplace=True)

# %%
names
# Out:
# Jane     90.0
# Bill     83.0
# Elon     85.0
# Tom      83.0
# Tim      95.0
# gagan    10.0
# dtype: float64

# %% [markdown]
# # Data Frame
#
# - Pandas DataFrame is two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes (rows and columns).
#
# - A Data frame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns. Pandas DataFrame consists of three principal components, the data, rows, and columns.
# ![image.png](attachment:image.png)
#
# Pandas DataFrame is created by loading the datasets from existing storage (which can be a SQL database, a CSV file, or an Excel file).

# %% [markdown]
# ### Creating Data Frame

# %%
import pandas as pd
data={
    "name":["Bill","Tom","Tim","John","Alex","Vanessa","Kate"],      
    "score":[90,80,85,75,95,60,65],      
    "sport":["Wrestling","Football","Skiing","Swimming","Tennis","Karete","Surfing"],      
    "gender":["M","M","M","M","F","F","F"]
}

df=pd.DataFrame(data)

# %%
df
# Out:
#       name  score      sport gender
# 0     Bill     90  Wrestling      M
# 1      Tom     80   Football      M
# 2      Tim     85     Skiing      M
# 3     John     75   Swimming      M
# 4     Alex     95     Tennis      F
# 5  Vanessa     60     Karete      F
# 6     Kate     65    Surfing      F

# %%
interested_col_df = df[["name", "score", "sport"]]

# %%
interested_col_df
# Out:
#       name  score      sport
# 0     Bill     90  Wrestling
# 1      Tom     80   Football
# 2      Tim     85     Skiing
# 3     John     75   Swimming
# 4     Alex     95     Tennis
# 5  Vanessa     60     Karete
# 6     Kate     65    Surfing

# %%
df=pd.DataFrame(data,columns=["name","sport","score"])
df
# Out:
#       name      sport  score
# 0     Bill  Wrestling     90
# 1      Tom   Football     80
# 2      Tim     Skiing     85
# 3     John   Swimming     75
# 4     Alex     Tennis     95
# 5  Vanessa     Karete     60
# 6     Kate    Surfing     65

# %%
df.head()  # default 5 rows
# Out:
#    name  score      sport gender
# 0  Bill     90  Wrestling      M
# 1   Tom     80   Football      M
# 2   Tim     85     Skiing      M
# 3  John     75   Swimming      M
# 4  Alex     95     Tennis      F

# %%
df.tail(5)
# Out:
#       name  score     sport gender
# 2      Tim     85    Skiing      M
# 3     John     75  Swimming      M
# 4     Alex     95    Tennis      F
# 5  Vanessa     60    Karete      F
# 6     Kate     65   Surfing      F

# %%
df.sample(n=3, random_state=42)
# Out:
#       name      sport  score
# 0     Bill  Wrestling     90
# 1      Tom   Football     80
# 5  Vanessa     Karete     60

# %%
df.describe()
# Out:
#            score
# count   7.000000
# mean   78.571429
# std    12.817399
# min    60.000000
# 25%    70.000000
# 50%    80.000000
# 75%    87.500000
# max    95.000000

# %%
df.columns
# Out:
# Index(['name', 'score', 'sport', 'gender'], dtype='object')

# %% [markdown]
# ### Accessing and indexing Data in Data Frame

# %%
df
# Out:
#       name  score      sport gender
# 0     Bill     90  Wrestling      M
# 1      Tom     80   Football      M
# 2      Tim     85     Skiing      M
# 3     John     75   Swimming      M
# 4     Alex     95     Tennis      F
# 5  Vanessa     60     Karete      F
# 6     Kate     65    Surfing      F

# %%
# Accessing a single column
name_data_frame = df["name"]
# name_data_frame
# Accessing multiple columns
df[["name","sport", "score"]]
# Out:
#       name      sport  score
# 0     Bill  Wrestling     90
# 1      Tom   Football     80
# 2      Tim     Skiing     85
# 3     John   Swimming     75
# 4     Alex     Tennis     95
# 5  Vanessa     Karete     60
# 6     Kate    Surfing     65

# %%
# # Accessing a specific row by index
print(df.iloc[2])  # Third row (index 2)

# # Accessing a range of rows using slicing
print(df.iloc[1:4, 0:2])  # Rows with indices 1, 2, 3
# Out:
# name        Tim
# sport    Skiing
# score        85
# Name: 2, dtype: object
#    name     sport
# 1   Tom  Football
# 2   Tim    Skiing
# 3  John  Swimming

# %% [markdown]
# Indexing with `.loc[]` and `.iloc[]`
#
# - `.loc[]`: Label-based indexing. It works with labels (row/column names).
# - `.iloc[]`: Position-based indexing. It works with integer positions (row/column indices).

# %%
df.set_index("name", inplace=True)

# %%
df
# Out:
#          score      sport gender
# name
# Bill        90  Wrestling      M
# Tom         80   Football      M
# Tim         85     Skiing      M
# John        75   Swimming      M
# Alex        95     Tennis      F
# Vanessa     60     Karete      F
# Kate        65    Surfing      F

# %%
df.reset_index(inplace=True)
df
# Out:
#       name  score      sport gender
# 0     Bill     90  Wrestling      M
# 1      Tom     80   Football      M
# 2      Tim     85     Skiing      M
# 3     John     75   Swimming      M
# 4     Alex     95     Tennis      F
# 5  Vanessa     60     Karete      F
# 6     Kate     65    Surfing      F

# %%
df
# Out:
#          score      sport gender
# name
# Bill        90  Wrestling      M
# Tom         80   Football      M
# Tim         85     Skiing      M
# John        75   Swimming      M
# Alex        95     Tennis      F
# Vanessa     60     Karete      F
# Kate        65    Surfing      F

# %%
# Accessing row by label (name)
print(df.loc["Bill"])  # Row with index 1
# Out:
# score            90
# sport     Wrestling
# gender            M
# Name: Bill, dtype: object

# %%
# Accessing specific value using labels
print(df.loc["Bill", "score"])  # score of the person at index 1
# Out:
# 90

# %%
# Accessing row by integer position
print(df.iloc[1])  # Second row (index 1)
# Out:
# score          80
# sport    Football
# sex             M
# Name: Tom, dtype: object

# %%
# Accessing specific value using integer positions
print(df.iloc[1, 2])  # Element at row 1, column 1
# Out:
# M

# %%
print(df.iloc[1, [0,2]])  # Element at row 1, column 0 and 2
# Out:
# score     80
# gender     M
# Name: Tom, dtype: object

# %% [markdown]
# ### Slicing
#
# - With `.loc[]`: Both the start and stop are included.
# - With `.iloc[]`: The stop is excluded.

# %%
# loc or iloc [row slicing, column slicing]

# %%
df
# Out:
#          score      sport gender
# name
# Bill        90  Wrestling      M
# Tom         80   Football      M
# Tim         85     Skiing      M
# John        75   Swimming      M
# Alex        95     Tennis      F
# Vanessa     60     Karete      F
# Kate        65    Surfing      F

# %%
# Using .loc for slicing (inclusive of end)
print(df.loc["Bill":"Tim", "score":"gender"])
# Out:
#       score      sport gender
# name
# Bill     90  Wrestling      M
# Tom      80   Football      M
# Tim      85     Skiing      M

# %%
# Using .iloc for slicing (exclusive of end)
print(df.iloc[1:3, 0:2])
# Out:
#       score     sport
# name
# Tom      80  Football
# Tim      85    Skiing

# %% [markdown]
# ### Filtering Data (Boolean Indexing)

# %%
# Filtering based on a condition (e.g., score > 80)
df[df["gender"] == 'M']
# Out:
#       score      sport gender
# name
# Bill     90  Wrestling      M
# Tom      80   Football      M
# Tim      85     Skiing      M
# John     75   Swimming      M

# %%
# Filtering based on multiple conditions
print(df[(df["score"] > 80) & (df["gender"] == "M")])
# Out:
#       score      sport gender
# name
# Bill     90  Wrestling      M
# Tim      85     Skiing      M

# %% [markdown]
# ### Sorting Data

# %%
# Sorting by score
print(df.sort_values("score", ascending=False))
# Out:
#          score      sport gender
# name
# Alex        95     Tennis      F
# Bill        90  Wrestling      M
# Tim         85     Skiing      M
# Tom         80   Football      M
# John        75   Swimming      M
# Kate        65    Surfing      F
# Vanessa     60     Karete      F

# %%
# Sorting by multiple columns (first by sex, then by score)
print(df.sort_values(by=["gender", "score"], ascending=[True, False]))
# Out:
#          score      sport gender
# name
# Alex        95     Tennis      F
# Kate        65    Surfing      F
# Vanessa     60     Karete      F
# Bill        90  Wrestling      M
# Tim         85     Skiing      M
# Tom         80   Football      M
# John        75   Swimming      M

# %% [markdown]
# ### Importing and exporting data

# %% [markdown]
# **With Read table for general delimated file**

# %%
import pandas as pd
df = pd.read_csv(r"datasets/data.txt", sep="\t") 
df
# Out:
#   name  score gender
# 0  Tim     80      M
# 1  Tom     85      M
# 2  Kim     70      F
# 3  Sam     90      M
# 4  Efe     75      M

# %% [markdown]
# **Reading with csv (1st row as header)**

# %%
df2=pd.read_csv("datasets/data2.txt")
df2
# Out:
#     Tom  80  M
# 0   Tim  85  M
# 1   Kim  70  M
# 2  Kate  90  F
# 3  Alex  75  F

# %%
import pandas as pd
df=pd.read_csv("datasets/data2.txt",
                 sep=",",
                 header=None,
                 names=["name", "age", "gender"]
              )
df
# Out:
#    name  age gender
# 0   Tom   80      M
# 1   Tim   85      M
# 2   Kim   70      M
# 3  Kate   90      F
# 4  Alex   75      F

# %% [markdown]
# **Specifying header**

# %%
df=pd.read_csv("datasets/data2.txt",
                 sep=",",
                 header=None, 
                 names=["name","score","gender"])
df
# Out:
#    name  score gender
# 0   Tom     80      M
# 1   Tim     85      M
# 2   Kim     70      M
# 3  Kate     90      F
# 4  Alex     75      F

# %% [markdown]
# **specifying index column**

# %%
df=pd.read_table("datasets/data2.txt", sep=",", header=None, names=["name","score","sex"], index_col="name")
df
# Out:
#       score sex
# name
# Tom      80   M
# Tim      85   M
# Kim      70   M
# Kate     90   F
# Alex     75   F

# %% [markdown]
# **Skip Rows**

# %%
df4=pd.read_csv("datasets/data4.txt")
df4
# Out:
#                           This data is collected by Mr. Gagan in behalf of government of Nepal: collection date:
# name                score                                                sex
# #scores of students NaN                                                  NaN
# Tim                 80                                                     M
# Kate                85                                                     F
# Alex                70                                                     M
# Tom                 90                                                     M
# Kim                 75                                                     F

# %%
df3=pd.read_table("datasets/data4.txt",
                  sep=",", 
                  skiprows=[0,2])
df3
# Out:
#    name  score sex
# 0   Tim     80   M
# 1  Kate     85   F
# 2  Alex     70   M
# 3   Tom     90   M
# 4   Kim     75   F

# %%
df3=pd.read_table("datasets/data4.txt",
                  sep=",", 
                  skiprows=[0,2],
                  usecols=[0,1])
df3
# Out:
#    name  score
# 0   Tim     80
# 1  Kate     85
# 2  Alex     70
# 3   Tom     90
# 4   Kim     75

# %% [markdown]
# **Reading with Excel**

# %%
df_excel = pd.read_excel('file_path.xlsx')

# %% [markdown]
# **We can also read directly by connecting database like**
#
# `conn = sqlite3.connect('database.db')`
#
# `df_sql = pd.read_sql('SELECT * FROM table_name', conn)`

# %% [markdown]
# **Exporting / Writing in CSV**

# %%
df=pd.read_csv("datasets/data.txt",sep="\t")
df
# Out:
#   name  score sex
# 0  Tim     80   M
# 1  Tom     85   M
# 2  Kim     70   F
# 3  Sam     90   M
# 4  Efe     75   M

# %%
df.to_csv("datasets/cleaned_data.csv", sep="\t")

# %% [markdown]
# ### GroupBy
#
# `groupby()` function in pandas is used to split the data into groups based on some criteria
#
# and we can apply a function to each group independently

# %%
data = {'Category': ['A', 'B', 'A', 'B', 'A'],
        'Values': [10, 20, 30, 40, 50]}

df = pd.DataFrame(data)

print(df)
# Out:
#   Category  Values
# 0        A      10
# 1        B      20
# 2        A      30
# 3        B      40
# 4        A      50

# %%
# Group by 'Category' and calculate the sum of 'Values'
grouped = df.groupby('Category')

# print(grouped)

grouped.sum()
# Out:
#           Values
# Category
# A             90
# B             60

# %%
grouped.mean()
# Out:
#           Values
# Category
# A           30.0
# B           30.0

# %% [markdown]
# **with Real Data**

# %%
import pandas as pd
game = pd.read_csv("datasets/vgsalesGlobale.csv")

# %%
game
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
game.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
game.isna().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
game.isnull().any()
# Out:
# Rank            False
# Name            False
# Platform        False
# Year             True
# Genre           False
# Publisher        True
# NA_Sales        False
# EU_Sales        False
# JP_Sales        False
# Other_Sales     False
# Global_Sales    False
# dtype: bool

# %%
game.dropna().describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16291.000000  16291.000000  16291.000000  16291.000000  16291.000000
# mean    8290.190228   2006.405561      0.265647      0.147731      0.078833
# std     4792.654450      5.832412      0.822432      0.509303      0.311879
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4132.500000   2003.000000      0.000000      0.000000      0.000000
# 50%     8292.000000   2007.000000      0.080000      0.020000      0.000000
# 75%    12439.500000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16291.000000  16291.000000
# mean       0.048426      0.540910
# std        0.190083      1.567345
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.480000
# ...

# %%
game.Global_Sales.mean()
# Out:
# 0.5374406555006628

# %%
group = game.groupby("Genre")

# %%
group["Global_Sales"].count()
# Out:
# Genre
# Action          3316
# Adventure       1286
# Fighting         848
# Misc            1739
# Platform         886
# Puzzle           582
# Racing          1249
# Role-Playing    1488
# Shooter         1310
# Simulation       867
# Sports          2346
# Strategy         681
# Name: Global_Sales, dtype: int64

# %%
group["Global_Sales"].describe() # Data describe for global sales on the group genre
# Out:
#                count      mean       std   min   25%    50%     75%    max
# Genre
# Action        3316.0  0.528100  1.156427  0.01  0.07  0.190  0.5000  21.40
# Adventure     1286.0  0.185879  0.513280  0.01  0.02  0.060  0.1600  11.18
# Fighting       848.0  0.529375  0.955965  0.01  0.08  0.210  0.5500  13.04
# Misc          1739.0  0.465762  1.314886  0.01  0.06  0.160  0.4100  29.02
# Platform       886.0  0.938341  2.585254  0.01  0.09  0.280  0.7900  40.24
# Puzzle         582.0  0.420876  1.561716  0.01  0.04  0.110  0.3075  30.26
# Racing        1249.0  0.586101  1.662437  0.01  0.07  0.190  0.5300  35.82
# Role-Playing  1488.0  0.623233  1.707909  0.01  0.07  0.185  0.5225  31.37
# Shooter       1310.0  0.791885  1.817263  0.01  0.08  0.230  0.7275  28.31
# Simulation     867.0  0.452364  1.195255  0.01  0.05  0.160  0.4200  24.76
# Sports        2346.0  0.567319  2.089716  0.01  0.09  0.220  0.5600  82.74
# ...

# %%
group["Global_Sales"].mean().plot(kind="bar")  # what are the arguments that we can provide in .plot() function in pandas
# Out:
# <Axes: xlabel='Genre'>

# %% [markdown]
# ## Missing Values

# %% [markdown]
# ## Merging, Joining, and Concatenating DataFrames
#
# `merge()` function is used to combine two DataFrames based on a common column (like SQL joins: inner', 'left', 'right', 'outer').
#
# python
# Copy

# %%
# Sample data
df1 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Charlie']})
df2 = pd.DataFrame({'ID': [1, 2, 4], 'Age': [25, 30, 22]})

# Merge DataFrames on 'ID'
merged_df = pd.merge(df1, df2, on='ID', how='inner')  # 'inner', 'left', 'right', 'outer'
print(merged_df)
